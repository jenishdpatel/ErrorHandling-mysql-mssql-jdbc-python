# %%
import pymysql.cursors
import pandas as pd
import pymysql

# %%
host = "db4free.net"
db = "exocube"
uname = "sample_jenish"
pas = "Jenu7492@patel"

# %%
Source_Table_Name = "employeeinfo"

# %%
def get_connection(host, uname, pas, db):
    try:
        sql_connection = pymysql.connect(host=host,user=uname,passwd=pas,db=db, cursorclass=pymysql.cursors.DictCursor, autocommit=True)
#This exception is raised for things that are not in control of the programmer. For e.g unexpected disconnect, error in memory allocation etc, selected database not exists.
    except pymysql.OperationalError as e:
        if e.args[0] == 2003:
            print('server not found')
        elif e.args[0] == 1044:
            print('database not found')
        elif e.args[0] == 1045:
            print('username or password incorrect')
    except:
        print("Unknown error occurred")   
    else:
        return sql_connection

# %%
def display_data(sql_disqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_disqry)
        if sql_exec:
            print(sql_exec)
            sql_data = pd.DataFrame(cursor.fetchall())
            result = sql_data.head(n=None)
            #display(sql_data.loc[1])
            display(result)
        else:
            print(sql_exec)
            print("No Record")
    except pymysql.ProgrammingError as e:
        if e.args[0] == 1146:
            print('table doesnt exist')
        elif e.args[0] == 1064:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(host, uname, pas, db)

# %%
sql_disqry = """SELECT * FROM {}""".format(Source_Table_Name)
display_data(sql_disqry, sql_conn)
# Out:
# 7
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>Amit</td><td>RnD</td></tr><tr><td>2</td><td>Akash</td><td>HR</td></tr><tr><td>3</td><td>Sumit</td><td>ML</td></tr><tr><td>4</td><td>Kokan</td><td>ML</td></tr><tr><td>5</td><td>Yash</td><td>DS</td></tr><tr><td>6</td><td>Suresh</td><td>Accounts</td></tr><tr><td>27</td><td>jeri</td><td>IT</td></tr></tbody></table></div>

# %%
def insert_data(sql_insqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_insqry)
        if sql_exec:
            print(sql_exec)
            print("Record Added")
        else:
            print(sql_exec)
            print("Not Added")
    except pymysql.ProgrammingError as e:
        if e.args[0] == 1146:
            print('table doesnt exist')
        elif e.args[0] == 1064:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(host, uname, pas, db)

# %%
sql_insqry = """INSERT INTO {}(name, department) VALUES ('vishal', 'IT')""".format(Source_Table_Name)
insert_data(sql_insqry, sql_conn)
# Out:
# 1
# Record Added

# %%
def update_data(sql_upqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_upqry)
        if sql_exec:
            print(sql_exec)
            print("Record Upadted")
        else:
            print(sql_exec)
            print("Not Upadted")
    except pymysql.ProgrammingError as e:
        if e.args[0] == 1146:
            print('table doesnt exist')
        elif e.args[0] == 1064:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(host, uname, pas, db)

# %%
sql_upqry = """UPDATE {} SET name = 'jeri' WHERE id = '27'""".format(Source_Table_Name)
update_data(sql_upqry, sql_conn)
# Out:
# 1
# Record Upadted

# %%
def delete_data(sql_delqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_delqry)
        if sql_exec:
            print(sql_exec)
            print("Record Deleted")
        else:
            print(sql_exec)
            print("Not Deleted")
    except pymysql.ProgrammingError as e:
        if e.args[0] == 1146:
            print('table doesnt exist')
        elif e.args[0] == 1064:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(host, uname, pas, db)

# %%
sql_delqry = """DELETE FROM {} WHERE id = '27'""".format(Source_Table_Name)
delete_data(sql_delqry, sql_conn)
# Out:
# 1
# Record Deleted
