# %%
import pandas as pd
import pymssql

# %%
jdbcHostname = "54.245.193.229" #"54.245.193.229" 
jdbcDatabase = "DEV" #"KAGGLE" 
jdbcPort = "1433" #1433 
jdbcUsername = "sa"
jdbcPassword = "WindowsSQL-123"

# %%
Source_Table_Name = "emp"

# %%
def get_connection(jdbcHostname, jdbcUsername, jdbcPassword, jdbcDatabase):
    try:
        sql_connection = pymssql.connect(host=jdbcHostname,user=jdbcUsername,password=jdbcPassword,database=jdbcDatabase, as_dict=True, autocommit=True)
#This exception is raised for things that are not in control of the programmer. For e.g unexpected disconnect, error in memory allocation etc, selected database not exists.
    except pymssql.OperationalError as e:
        print("connection failed")
    except:
        print("Unknown error occurred")
    else:
        return sql_connection

# %%
def display_data(sql_disqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        cursor.execute(sql_disqry)
        sql_exec = cursor.fetchone()
        if len(sql_exec) > 0:
            sql_data = pd.DataFrame(cursor.fetchall())
            result = sql_data.head(n=None)
            #display(sql_data.loc[1])
            display(result)
        else:
            print("No Record")
    except pymssql.ProgrammingError as e:
        if e.args[0] == 208:
            print('table doesnt exist')
        elif e.args[0] == 102:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(jdbcHostname, jdbcUsername, jdbcPassword, jdbcDatabase)

# %%
sql_disqry ="(Select * from {})".format(Source_Table_Name)
display_data(sql_disqry, sql_conn)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698.0</td><td>1981-02-20</td><td>1600</td><td>300.0</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698.0</td><td>1981-02-22</td><td>1250</td><td>500.0</td><td>30</td></tr><tr><td>7560</td><td>vishal</td><td>analyst</td><td>7856.0</td><td>1994-06-27</td><td>15000</td><td>null</td><td>20</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839.0</td><td>1981-02-04</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698.0</td><td>1981-09-28</td><td>1250</td><td>1400.0</td><td>30</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839.0</td><td>1981-01-05</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839.0</td><td>1981-09-06</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566.0</td><td>1987-07-13</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-11-17</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698.0</td><td>1981-09-08</td><td>1500</td><td>0.0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788.0</td><td>1987-07-13</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698.0</td><td>1981-12-03</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566.0</td><td>1981-03-12</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782.0</td><td>1982-01-23</td><td>1300</td><td>null</td><td>10</td></tr></tbody></table></div>

# %%
def insert_data(sql_insqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_insqry)
        if cursor.rowcount:
            print(cursor.rowcount)
            print("Record Added")
        else:
            print(cursor.rowcount)
            print("Not Added")
    except pymssql.ProgrammingError as e:
        if e.args[0] == 208:
            print('table doesnt exist')
        elif e.args[0] == 102:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(jdbcHostname, jdbcUsername, jdbcPassword, jdbcDatabase)

# %%
sql_insqry = """INSERT INTO {}(empno, ename, job, mgr, hiredate, sal, deptno) VALUES (7560, 'jenish', 'analyst', 7856, '1994-06-27', 15000, 20)""".format(Source_Table_Name)
insert_data(sql_insqry, sql_conn)
# Out:
# 1
# Record Added

# %%
def update_data(sql_upqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_upqry)
        if cursor.rowcount:
            print(cursor.rowcount)
            print("Record Upadted")
        else:
            print(cursor.rowcount)
            print("Not Upadted")
    except pymssql.ProgrammingError as e:
        if e.args[0] == 208:
            print('table doesnt exist')
        elif e.args[0] == 102:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(jdbcHostname, jdbcUsername, jdbcPassword, jdbcDatabase)

# %%
sql_upqry = """UPDATE {} SET ename = 'vishal' WHERE empno = '7560' """.format(Source_Table_Name)
update_data(sql_upqry, sql_conn)
# Out:
# 1
# Record Upadted

# %%
def delete_data(sql_delqry, sql_conn):
    try:
        cursor = sql_conn.cursor()
        sql_exec = cursor.execute(sql_delqry)
        if cursor.rowcount:
            print(cursor.rowcount)
            print("Record Deleted")
        else:
            print(cursor.rowcount)
            print("Not Deleted")
    except pymssql.ProgrammingError as e:
        if e.args[0] == 208:
            print('table doesnt exist')
        elif e.args[0] == 102:
            print('sql query syntax error')  
    finally:
        sql_conn.close()

# %%
sql_conn = get_connection(jdbcHostname, jdbcUsername, jdbcPassword, jdbcDatabase)

# %%
sql_delqry = """DELETE FROM {} WHERE empno = '7560'""".format(Source_Table_Name)
delete_data(sql_delqry, sql_conn)
# Out:
# 1
# Record Deleted
